# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/comparison-of-north-american-ski-resorts/north_american_ski_resort_data.csv

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
resort_filepath="../input/comparison-of-north-american-ski-resorts/north_american_ski_resort_data.csv"
resort_data=pd.read_csv(resort_filepath)

# %%
resort_data
# Out:
#                          Resort                    City          State  \
# 0                    Afton Alps                   Afton      Minnesota
# 1     Pomerelle Mountain Resort                  Albion          Idaho
# 2                   Sandia Peak             Albuquerque     New Mexico
# 3    Bear Creek Mountain Resort               Allentown   Pennsylvania
# 4         Grand Targhee Resort                     Alta        Wyoming
# ..                          ...                     ...            ...
# 457            Abenaki Ski Area               Wolfeboro  New Hampshire
# 458          Wachusett Mountain               Worcester  Massachusetts
# 459               Mountain High              Wrightwood     California
# 460                  White Pass                  Yakima     Washington
# 461                 Badger Pass  Yosemite National Park     California
#
#      Peak elevation (ft)  Base elevation (ft)  Vertical drop (ft)  \
# ...

# %%
resort_data1=resort_data[:25]

# %%
resort_data1
# Out:
#                                                Resort         City  \
# 0                                          Afton Alps        Afton
# 1                           Pomerelle Mountain Resort       Albion
# 2                                         Sandia Peak  Albuquerque
# 3                          Bear Creek Mountain Resort    Allentown
# 4                               Grand Targhee Resort          Alta
# 5                                           Discovery     Anaconda
# 6                                       Arctic Valley    Anchorage
# 7                                             Hilltop    Anchorage
# 8                              Angel Fire Resort [41]   Angel Fire
# 9                                         Bear Valley  Angels Camp
# 10                                Kettlebowl Ski Area       Antigo
# 11                                  Blizzard Mountain         Arco
# 12  Powers Bluff County Park and Winter Recreation...        Arpin
# ...

# %%
resort_data.tail()
# Out:
#                  Resort                    City          State  \
# 457    Abenaki Ski Area               Wolfeboro  New Hampshire
# 458  Wachusett Mountain               Worcester  Massachusetts
# 459       Mountain High              Wrightwood     California
# 460          White Pass                  Yakima     Washington
# 461         Badger Pass  Yosemite National Park     California
#
#      Peak elevation (ft)  Base elevation (ft)  Vertical drop (ft)  \
# 457                  815                  600                 215
# 458                 2006                 1006                1000
# 459                 8200                 6600                1600
# 460                 6500                 4500                2000
# 461                 8000                 7200                 800
#
#      Skiable acreage  Total trails  Total lifts  Avg annual snowfall (in)  \
# 457               18             7            2                       186
# ...

# %%
resort_data.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<AxesSubplot:title={'center':'Peak elevation (ft)'}>,
#         <AxesSubplot:title={'center':'Base elevation (ft)'}>,
#         <AxesSubplot:title={'center':'Vertical drop (ft)'}>],
#        [<AxesSubplot:title={'center':'Skiable acreage'}>,
#         <AxesSubplot:title={'center':'Total trails'}>,
#         <AxesSubplot:title={'center':'Total lifts'}>],
#        [<AxesSubplot:title={'center':'Avg annual snowfall (in)'}>,
#         <AxesSubplot:title={'center':'Lift ticket (USD)'}>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ## Through these scatter plots we can see that there is a slight correlation between "Lift ticket (USD)" and many other metrics

# %%
# Scatter plots to show correlations between 'Lift ticket (USD)' and other various metrics
for i in range(3, len(resort_data.columns), 5):
    sns.pairplot(data=resort_data,x_vars=resort_data.columns[i:i+5],y_vars=['Lift ticket (USD)'])

# %% [markdown]
# ## We can see through the scatter plots that only 'Vertical drop' and 'Total trails' show a slight correlation to 'Skiable acreage'

# %%
# Scatter plots to show correlation between 'Skiable acreage' and other various metrics
for i in range(3, len(resort_data.columns), 5):
    sns.pairplot(data=resort_data,x_vars=resort_data.columns[i:i+5],y_vars=['Skiable acreage'])

# %% [markdown]
# ## We can see through the scatter plots that only 'Vertical drop' and 'Total trails' show a slight correlation to 'Skiable acreage'

# %%
sns.scatterplot(x='Total trails', y='Total lifts', data=resort_data)
# Out:
# <AxesSubplot:xlabel='Total trails', ylabel='Total lifts'>

# %%
# Various boxplots to identify key statistics and any outliers
boxplot = resort_data.boxplot(column=['Peak elevation (ft)', 'Base elevation (ft)', 'Vertical drop (ft)', 'Skiable acreage'], rot=45)

# %%
boxplot1 = resort_data.boxplot(column=['Total trails', 'Lift ticket (USD)'], rot=45)

# %%
boxplot2 = resort_data.boxplot(column=['Avg annual snowfall (in)'], rot=45)

# %%
boxplot3 = resort_data.boxplot(column=['Total lifts'], rot=45)

# %% [markdown]
# ### Outliers can be ignored

# %% [markdown]
# # Top 10 Ski Resorts by average annual snowfall

# %%
# Top 10 Ski Resorts by Average Annual Snowfall (in)
df1 = resort_data.filter(['Avg annual snowfall (in)', 'Resort'], axis=1)
df1 = df1.sort_values(by='Avg annual snowfall (in)', ascending=False)

# %%
snow = df1['Avg annual snowfall (in)'].head(10)
res = df1['Resort'].head(10)

# %%
fig = plt.figure(figsize=(10, 8))
plt.bar(res[0:10], snow[0:10])
plt.xticks(rotation=45)
plt.title('Top 10 Ski Resorts by Average Annual Snowfall (in)')
plt.ylabel('Average Annual Snowfall (in)')
plt.show()
